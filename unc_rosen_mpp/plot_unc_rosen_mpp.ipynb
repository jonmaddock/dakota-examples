# %% [markdown]
# # Plot Uncertain Rosenbrock Local Reliability Study
#
# After an epistemic uncertainty has been applied to constraints 1 (squared) and 2 (linear, with linear shift), a reliability analysis is plotted.

# %%
import pandas as pd
from pathlib import Path
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Read in output file
output_filename = Path("responses_stdout.txt")
with open(output_filename, "r") as output_file:
    for line_no, line_str in enumerate(output_file.readlines()):
        if "Cumulative Distribution Function (CDF)" in line_str:
            start = line_no + 3
        elif "Iterator local_reliability completed" in line_str:
            finish = line_no - 2
    
cdf_data = np.loadtxt(output_filename, skiprows=start, max_rows=(finish-start))
cdf_data
# Out:
# array([[-2.37483560e-01,  7.43886363e-10,  6.04568419e+00,
#          6.04568419e+00],
#        [ 1.36000003e+00,  2.49792464e-30,  1.13844921e+01,
#          1.13844921e+01],
#        [-1.99993676e-01,  2.32256115e-03,  2.83066584e+00,
#          2.83066584e+00],
#        [-9.99999536e-02,  2.24213310e-02,  2.00612736e+00,
#          2.00612736e+00],
#        [ 2.15152163e-09,  5.68354285e-02,  1.58190676e+00,
#          1.58190676e+00],
#        [ 1.00000067e-01,  1.01184651e-01,  1.27483034e+00,
#          1.27483034e+00],
#        [ 2.00000000e-01,  1.52428374e-01,  1.02607391e+00,
#          1.02607391e+00],
#        [ 3.00000000e-01,  2.08180832e-01,  8.12749555e-01,
#          8.12749555e-01],
#        [ 4.00000000e-01,  2.66500039e-01,  6.23432909e-01,
#          6.23432909e-01]])

# %%
fig, ax = plt.subplots()
ax.plot(cdf_data[:,0], cdf_data[:,1], marker="o")
ax.set_xlabel("Response (sum of constraints)")
ax.set_ylabel("CDF")
ax.set_title("Local reliability")
# Out:
# Text(0.5, 1.0, 'Local reliability')

# %% [markdown]
# Local reliability: CDF of sum of constraints. Not sure what this shows.

# %%
fig, ax = plt.subplots()
ax.plot(cdf_data[:,0], cdf_data[:,2], marker="o")
ax.set_xlabel("Response (sum of constraints)")
ax.set_ylabel("Reliability")
ax.set_title("Local reliability")
# Out:
# Text(0.5, 1.0, 'Local reliability')

# %% [markdown]
# Not sure what this plot is showing: how should reliability be plotted?
